# %%
# Import Dependencies
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
# Load the Size History by County csv to a DataFrame
population_data_path = "../raw_data/Electric_Vehicle_Population_Data.csv"
population_data = pd.read_csv(population_data_path)

# %%
# Preview data
population_data.head()
# Out:
#    VIN (1-10)     County         City State  ZIP Code  Model Year    Make  \
# 0  WA1VABGE7M    Douglas        OMAHA    NE     68102        2021    AUDI
# 1  WBY7Z2C52J       King      SEATTLE    WA     98144        2018     BMW
# 2  KNDCC3LG2L  Jefferson     CHIMACUM    WA     98325        2020     KIA
# 3  JN1AZ0CP4B       King  WOODINVILLE    WA     98072        2011  NISSAN
# 4  JTDKARFP6H      Clark        CAMAS    WA     98607        2017  TOYOTA
#
#          Model                   Electric Vehicle Type  \
# 0       E-TRON          Battery Electric Vehicle (BEV)
# 1           I3          Battery Electric Vehicle (BEV)
# 2         NIRO          Battery Electric Vehicle (BEV)
# 3         LEAF          Battery Electric Vehicle (BEV)
# 4  PRIUS PRIME  Plug-in Hybrid Electric Vehicle (PHEV)
#
#   Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 0           Clean Alternative Fuel Vehicle Eligible             222
# ...

# %%
# Drop NaN values
population_data_cleaned = population_data.dropna()
population_data_cleaned.head()
# Out:
#    VIN (1-10)     County         City State  ZIP Code  Model Year    Make  \
# 1  WBY7Z2C52J       King      SEATTLE    WA     98144        2018     BMW
# 2  KNDCC3LG2L  Jefferson     CHIMACUM    WA     98325        2020     KIA
# 3  JN1AZ0CP4B       King  WOODINVILLE    WA     98072        2011  NISSAN
# 4  JTDKARFP6H      Clark        CAMAS    WA     98607        2017  TOYOTA
# 5  WBY1Z2C58F       King    SAMMAMISH    WA     98074        2015     BMW
#
#          Model                   Electric Vehicle Type  \
# 1           I3          Battery Electric Vehicle (BEV)
# 2         NIRO          Battery Electric Vehicle (BEV)
# 3         LEAF          Battery Electric Vehicle (BEV)
# 4  PRIUS PRIME  Plug-in Hybrid Electric Vehicle (PHEV)
# 5           I3          Battery Electric Vehicle (BEV)
#
#   Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 1           Clean Alternative Fuel Vehicle Eligible             114
# ...

# %%
# Check unique values for cities to ensure all data is useable
population_data["City"].unique()
# Out:
# array(['OMAHA', 'SEATTLE', 'CHIMACUM', 'WOODINVILLE', 'CAMAS',
#        'SAMMAMISH', 'EDGEWOOD', 'ISSAQUAH', 'SHORELINE', 'REDMOND',
#        'VANCOUVER', 'KENMORE', 'FOX ISLAND', 'OLYMPIA', 'KIRKLAND',
#        'TACOMA', 'BURIEN', 'RENTON', 'GIG HARBOR', 'ROY', 'SEATAC',
#        'BELLEVUE', 'FIFE', 'KENT', 'LEMOORE', 'MONROE', 'NORTH BEND',
#        'RAYMOND', 'BLAINE', 'EDMONDS', 'TUKWILA', 'AUBURN',
#        'PORT ORCHARD', 'RICHLAND', 'BAINBRIDGE ISLAND', 'BELLINGHAM',
#        'ARLINGTON', 'PASCO', 'COVINGTON', 'NORMANDY PARK', 'ENUMCLAW',
#        'WENATCHEE', 'GOLDENDALE', 'EASTSOUND', 'PORT ANGELES',
#        'LIBERTY LAKE', 'BRIER', 'LAKEBAY', 'MILL CREEK', 'SPOKANE',
#        'MOUNTLAKE TERRACE', 'SNOHOMISH', 'SUNNYSIDE', 'RIDGEFIELD',
#        'ANACORTES', 'LYNNWOOD', 'LA CONNER', 'BOTHELL',
#        'UNIVERSITY PLACE', 'FIRCREST', 'POULSBO', 'MERCER ISLAND', 'MEAD',
#        'MAPLE VALLEY', 'PORT TOWNSEND', 'NASELLE', 'MARYSVILLE',
# ...

# %%
# Check unique values for counties to ensure all data is useable
population_data_cleaned["County"].unique()
# Out:
# array(['King', 'Jefferson', 'Clark', 'Pierce', 'Thurston', 'Snohomish',
#        'Pacific', 'Whatcom', 'Kitsap', 'Benton', 'Franklin', 'Chelan',
#        'Klickitat', 'San Juan', 'Clallam', 'Spokane', 'Yakima', 'Skagit',
#        'Wahkiakum', 'Okanogan', 'Walla Walla', 'Grant', 'Cowlitz',
#        'Island', 'Douglas', 'Kittitas', 'Skamania', 'Lewis', 'Whitman',
#        'Stevens', 'Grays Harbor', 'Lincoln', 'Mason', 'Pend Oreille',
#        'Adams', 'Ferry', 'Asotin', 'Garfield', 'Columbia'], dtype=object)

# %%
# Check unique values for states to ensure all data is useable
population_data_cleaned["State"].unique()
# Out:
# array(['WA'], dtype=object)

# %%
# Value counts for counties
population_data_cleaned["County"].value_counts()
# Out:
# King            45116
# Snohomish        9192
# Pierce           6530
# Clark            4986
# Thurston         3283
# Kitsap           3085
# Whatcom          2356
# Spokane          2095
# Benton           1088
# Island           1068
# Skagit           1031
# San Juan          615
# Jefferson         585
# Clallam           547
# Chelan            528
# Yakima            486
# Cowlitz           455
# Mason             442
# Lewis             346
# Grays Harbor      311
# Kittitas          277
# Franklin          273
# Walla Walla       234
# Grant             220
# Douglas           169
# Whitman           148
# Klickitat         146
# Pacific           128
# Skamania          101
# Stevens            95
# Okanogan           94
# Asotin             53
# Adams              34
# Lincoln            26
# Pend Oreille       26
# Wahkiakum          26
# Ferry              18
# Columbia            8
# Garfield            4
# Name: County, dtype: int64

# %%
# Export cleaned csv file to cleaned_data folder
population_data_cleaned.to_csv("../cleaned_data/Electric_Vehicle_Population_Data_Cleaned.csv",index=False, header=True)
